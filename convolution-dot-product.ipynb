# %%
import numpy as np

# %%
x = np.array([1, 2, 3])
y = np.array([7, 8, 9])

# %%
# x = np.array([3, 2, 1, 0, 0])
# y = np.array([5, 3, 7, 1, 2])

# %%
c = np.convolve(x, y)

# %%
c
# Out:
# array([ 7, 22, 46, 42, 27])

# %%
np.dot(x, y[::-1])
# Out:
# 46

# %%
x1 = np.array([1, 2, 3, 0, 0])
y1 = np.array([
    [7, 0, 0, 0, 0],
    [8, 7, 0, 0, 0],
    [9, 8, 7, 0, 0],
    [0, 9, 8, 7, 0],
    [0, 0, 9, 8, 7],
])

# %%
np.matmul(y1, x1)
# Out:
# array([ 7, 22, 46, 42, 27])

# %%
# np.matmul(np.pad(x, (1,1)).reshape(5, 1), np.pad(y, (1,1)).reshape(1, 5))
# Out:
# array([[ 0,  0,  0,  0,  0],
#        [ 0,  7,  8,  9,  0],
#        [ 0, 14, 16, 18,  0],
#        [ 0, 21, 24, 27,  0],
#        [ 0,  0,  0,  0,  0]])

# %%
24+18
# Out:
# 42

# %%
np.pad(x, (1,1))
# Out:
# array([0, 1, 2, 3, 0])
