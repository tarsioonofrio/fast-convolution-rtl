# %%
from sympy import symbols, eye
from sympy.matrices import Matrix

# %%
d2, d1, d0 = symbols("d_2, d_1, d_0")

# %%
g1, g0 = symbols("g_1, g_0")

# %%
s1, s0 = symbols("s_1, s_0")

# %%
x = symbols("x")

# %%
dx = d1*x + d0

# %%
gx = g1*x + g0

# %%
sx = gx*dx

# %%
sx
# Out:
# (d_0 + d_1*x)*(g_0 + g_1*x)

# %%
b2, b1, b0 = symbols("b_1, b_1, b_0")

# %%
ma = Matrix([[1, 1], [1, 0], [0, 1]])
ma
# Out:
# Matrix([
# [1, 1],
# [1, 0],
# [0, 1]])

# %%
md = Matrix([d0, d1 - d2])
md
# Out:
# Matrix([
# [      d_0],
# [d_1 - d_2]])

# %%
ma*mb
# Out:
# Matrix([
# [d_0 + d_1],
# [      d_0],
# [      d_1]])

# %%
mg = Matrix([
    [g0 , 0, 0],
    [0, g1 - g0, 0], 
    [0, 0, g1 + g0]]
)
md
# Out:
# Matrix([
# [g_0,          0,         0],
# [  0, -g_0 + g_1,         0],
# [  0,          0, g_0 + g_1]])

# %%
mc = Matrix([
    [1, 0, -1],
    [1, 1,  0]
])
mc
# Out:
# Matrix([
# [1, 0, -1],
# [1, 1,  0]])

# %%
s =  mc * mg * ma * mb
s
# Out:
# Matrix([
# [d_0*g_0 - d_1*g_1],
# [d_0*g_1 + d_1*g_0]])
