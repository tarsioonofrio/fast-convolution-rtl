# %%
import itertools

import sympy as sy
import numpy as np

# %%
from utils import plot_pdf

# %%
# doc = fitz.open('Blahut_2010_Fast algorithms for signal processing.pdf')

# %%
x = sy.symbols("x")
x
# Out:
# x

# %%
root = sy.solve(x**2+1, x)
sy.Matrix(root)
# Out:
# Matrix([
# [-I],
# [ I]])

# %%
prod = np.prod([x+r for r in root])
prod
# Out:
# (x - I)*(x + I)

# %%
sy.expand(prod)
# Out:
# x**2 + 1

# %%
root = sy.solve(x**3+1, x)
sy.Matrix(root)
# Out:
# Matrix([
# [               -1],
# [1/2 - sqrt(3)*I/2],
# [1/2 + sqrt(3)*I/2]])

# %%
sy.expand((x+1)*(x+sy.I)*(x-sy.I))
# Out:
# x**3 + x**2 + x + 1

# %%
factor = sy.factor(x**3+1, modulus=17)
factor
# Out:
# (x + 1)*(x**2 - x + 1)

# %%
root = sy.solve(x**3+x+1, x)
sy.Matrix(root)
# Out:
# Matrix([
# [ 1/((-1/2 - sqrt(3)*I/2)*(27/2 + 3*sqrt(93)/2)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(27/2 + 3*sqrt(93)/2)**(1/3)/3],
# [-(-1/2 + sqrt(3)*I/2)*(27/2 + 3*sqrt(93)/2)**(1/3)/3 + 1/((-1/2 + sqrt(3)*I/2)*(27/2 + 3*sqrt(93)/2)**(1/3))],
# [                                             -(27/2 + 3*sqrt(93)/2)**(1/3)/3 + (27/2 + 3*sqrt(93)/2)**(-1/3)]])

# %%
360/60
# Out:
# 6.0

# %%
root = sy.solve(x**3+1, x)
sy.Matrix(root)
# Out:
# Matrix([
# [               -1],
# [1/2 - sqrt(3)*I/2],
# [1/2 + sqrt(3)*I/2]])
