# %%
data = [
    b'0000',
    b'0001',
    b'0010',
    b'0011',
    b'0100',
    b'0101',
    b'0110',
    b'0111',
    b'1000',
    b'1001',
    b'1010',
    b'1011',
    b'1100',
    b'1101',
    b'1110',
    b'1111',
]

codewords = [
    b'0000000'
    b'0001011'
    b'0010111'
    b'0011100'
    b'0100110'
    b'0101101'
    b'0110001'
    b'0111010'
    b'1000101'
    b'1001110'
    b'1010010'
    b'1011001'
    b'1100011'
    b'1101000'
    b'1110100'
    b'1111111'
]

code = [
    b'000'
    b'011'
    b'111'
    b'100'
    b'110'
    b'101'
    b'001'
    b'010'
    b'101'
    b'110'
    b'010'
    b'001'
    b'011'
    b'000'
    b'100'
    b'111'
]

# %%
data
# Out:
# [b'0000',
#  b'0001',
#  b'0010',
#  b'0011',
#  b'0100',
#  b'0101',
#  b'0110',
#  b'0111',
#  b'1000',
#  b'1001',
#  b'1010',
#  b'1011',
#  b'1100',
#  b'1101',
#  b'1110',
#  b'1111']
